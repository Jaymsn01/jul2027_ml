# %%
def find_m_c(x1, y1, x2, y2):
    # find y = mx + c
    # 1	3
    # 2	7
    change_in_y_per_change_in_x = (y2-y1)/(x2-x1) # (7-3)/(2-1)
    change_in_y_when_x1_becomes_0 = y1 - x1 * change_in_y_per_change_in_x
    return m , c

# %%
def find_m_c(x1, y1, x2, y2):
    # find y = mx + c
    # 1	3
    # 2	7
    m = (y2-y1)/(x2-x1) # (7-3)/(2-1)
    c = y1 - m * x1
    # c = y2 - m * x2
    return m , c

# %%
m, c = find_m_c(1, 3, 2, 7)
print(m, c)
# Out:
# 4.0 -1.0

# %%
m, c = find_m_c(1, 10, 1.2, 50)
print(m, c)
# Out:
# 200.00000000000006 -190.00000000000006

# %%
def find_m_c(x1, y1, x2, y2):
    # find y = mx + c
    # 1	3
    # 2	7
    m = (y2-y1)/(x2-x1) # (7-3)/(2-1)
    # c = y1 - m * x1
    c = y2 - m * x2
    return m , c

# %%
# training 
def fit(x1, y1, x2, y2):
    m = (y2-y1)/(x2-x1) # (7-3)/(2-1)
    c = y1 - m * x1
    return m , c


def predict(m, c, x):
    return m * x + c

# %%
m, c = fit(1, 10, 1.2, 50)
print(m, c)

y = predict(m, c, .1)
print(y)
y = predict(m, c, 2)
print(y)
# Out:
# 200.00000000000006 -190.00000000000006
# -170.00000000000006
# 210.00000000000006

# %%
m, c = fit(1, 3, 2, 7)
y = predict(m, c, .5)
print(y)
y = predict(m, c, -100)
print(y)
# Out:
# 1.0
# -401.0

# %%
1   3
1   4
m = (4-3)/(1-1)
