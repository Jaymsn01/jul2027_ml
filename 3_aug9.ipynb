# %% [raw]
# 1. A grayscale image is basically 2D - width, height
# 2. a colored image 3D - w, x, color
# 3. Video is how many - w, x, color, time - 4D
# 4.

# %%
x = 10
arr = [10,200,"sandeep", [4,5]]
print(arr)
# Out:
# [10, 200, 'sandeep', [4, 5]]

# %%
arr[0]
# Out:
# 10

# %%
arr[1]
# Out:
# 200

# %%
arr[2]
# Out:
# 'sandeep'

# %%
arr[3][0]
# Out:
# 4

# %%
grey_image = [
    [0, 100, 255],
    [45, 20, 255],
    [0, 67, 100]
]

import matplotlib.pyplot as plt 

plt.imshow(grey_image, cmap="grey")

# %%
# 2x2
red_layer = [
    [0, 255],
    [100, 255]
]
plt.imshow(red_layer, cmap="grey")

# %%
green_layer = [
    [255, 0],
    [100, 255]
]
plt.imshow(green_layer, cmap="grey")

# %%
blue_layer = [
    [255, 0],
    [100, 0]
]
plt.imshow(blue_layer, cmap="grey")

# %%
from termcolor import colored


red_layer = [
    [255, 0],
    [0, 100]
]
green_layer = [
    [0, 255],
    [0, 100]
]
blue_layer = [
    [0, 0],
    [255, 100]
]
colored = [
    [ [255, 0, 0] , [0, 255, 0] ],
    [ [0, 0, 255] , [100, 100, 100]]
]
plt.imshow(colored)

# %%
colored = [
    [ [0, 0, 255] , [255, 0, 255], [255, 255, 0], [255, 255, 255]],
    [ [255, 0, 0] , [0, 255, 0], [0, 255, 255] , [0, 0, 0]],
    [ [0, 0, 255] , [255, 0, 255], [255, 255, 0], [255, 255, 255]]
]
plt.imshow(colored)

# Exercise: Try different permutation of values and figure out the colors.

# %%
cat = plt.imread('cat.jpg')
cat.shape
# Out:
# (1280, 853, 3)

# %%
cat[0][0]
# Out:
# array([193, 160, 151], dtype=uint8)

# %%
cat.ndim
# Out:
# 3

# %%
# cat video - (5000, 1280, 853, 3) - 4D

# %%
1/10 -> 10**-1

# %%
import math
math.log10(.1)
# Out:
# -1.0

# %%
# Audio???
# /Users/sandeepgiri/Documents/my_audio.wav

from scipy.io import wavfile

# Load audio
sample_rate, audio = wavfile.read("/Users/sandeepgiri/Documents/my_audio.wav")

print("Sample rate:", sample_rate)
print("Shape:", audio.shape)
print("Data type:", audio.dtype)
print("First 10 samples:", audio[:10])
# Out:
# Sample rate: 44100
# Shape: (462946,)
# Data type: int16
# First 10 samples: [-276  -75  402  428 -115 -454 -222  223  421  156]

# %%
audio.shape
# Out:
# (462946,)

# %%
audio
# Out:
# array([-276,  -75,  402, ...,  212,  212,  212],
#       shape=(462946,), dtype=int16)

# %%
audio.ndim
# Out:
# 1

# %%
462946 / 44100
# Out:
# 10.49764172335601

# %%
# A list of videos is 5D
