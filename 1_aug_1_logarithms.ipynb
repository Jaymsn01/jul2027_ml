# %%
1+1
# Out:
# 2

# %% [markdown]
# # Links
#
# https://github.com/cloudxlab/jul2027_ml
#
# https://learnbyinventing.com/getting_started/index.html
#
# https://cloudxlab.com/course/my#course-211
#
# https://pyquest.io/

# %%
# base 10
log(10) -> 1
log(100) -> 2
log(1000) -> 3
log(10000) -> 4
log(10**n) --> n


# log is basically number of zeros.

alog(2) -> 10**2

# %%
# log(something) = 5

#what is something?
10**5

# %%
10**5
# Out:
# 100000

# %%
import math

math.log10(10)
# Out:
# 1.0

# %%
math.log10(10)

# %%
math.log10(10**5)
# Out:
# 5.0

# %%
from math import *

# %%
log10(100000000)
# Out:
# 8.0

# %%
# what is log10(5)
log(1) -> 10**0 --> 0
log(10) -> 1

# %%
# We are using base 10

log(100, 10)
# Out:
# 2.0

# %%
10**.5
# Out:
# 3.1622776601683795

# %%
log10(3.1622776601683795)
# Out:
# 0.5

# %%
log(25, 5)
# Out:
# 2.0

# %%
log(5**2, 5)

# %%
5**0 -> 1
5**1 -> 5
5**2 -> 25

# %%
5**6
# Out:
# 15625

# %%
log(15625, 5)
# Out:
# 6.000000000000001

# %%
# 5**x = 15625
x = log(15625, 5)
x
# Out:
# 6.000000000000001

# %%
log(125, 5) # log(5**3, 5)
# Out:
# 3.0000000000000004

# %%
log(2, 2)
# Out:
# 1.0

# %%
log(8, 2)
# Out:
# 3.0

# %%
log(9, 3)
# Out:
# 2.0

# %%
log(27, 3)
# Out:
# 3.0

# %%
log(9*27, 3)
# Out:
# 4.999999999999999

# %%
# log10(5)

# %%
log10(1)
# Out:
# 0.0

# %%
log10(10)
# Out:
# 1.0

# %%
guess = 0.5

10**guess # this should give us....
# Out:
# 3.1622776601683795

# %%
lo, hi = .5, 1
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# 0.75
# 5.623413251903491

# %%
lo, hi = .5, 0.75
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# 0.625
# 4.216965034285822

# %%
10**.625, 10**.75
# Out:
# (4.216965034285822, 5.623413251903491)

# %%
lo, hi = 0.625, 0.75
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# 0.6875
# 4.869675251658631

# %%
lo = mid
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# 0.71875
# 5.232991146814947

# %%
hi = mid
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# 0.703125
# 5.0480657166674705

# %%
hi = mid
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# 0.6953125
# 4.958068241684655

# %%
lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.6953125, hi: 0.703125
# 0.69921875
# 5.002864610575233

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.6953125, hi: 0.69921875
# 0.697265625
# 4.980416061248411

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.697265625, hi: 0.69921875
# 0.6982421875
# 4.991627716362687

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.6982421875, hi: 0.69921875
# 0.69873046875
# 4.997243005033611

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.69873046875, hi: 0.69921875
# 0.698974609375
# 5.00005301775164

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.69873046875, hi: 0.698974609375
# 0.6988525390625
# 4.998647813934943

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.6988525390625, hi: 0.698974609375
# 0.69891357421875
# 4.9993503664719325

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.69891357421875, hi: 0.698974609375
# 0.698944091796875
# 4.999701679768079

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
print(f"lo: {lo}, hi: {hi}")
mid = (lo + hi)/2
print(mid)
print(10**mid)
# Out:
# lo: 0.698944091796875, hi: 0.698974609375
# 0.6989593505859375
# 4.999877345673824

# %%
for i in range(100):
  if 10**mid > 5:
    hi = mid
  else:
    lo = mid
  print(f"lo: {lo}, hi: {hi}")
  mid = (lo + hi)/2
  print(mid)
  print(10**mid)
# Out:
# lo: 0.6989699900150299, hi: 0.6989700049161911
# 0.6989699974656105
# 4.999999920901502
# lo: 0.6989699974656105, hi: 0.6989700049161911
# 0.6989700011909008
# 4.999999963790491
# lo: 0.6989700011909008, hi: 0.6989700049161911
# 0.698970003053546
# 4.999999985234986
# lo: 0.698970003053546, hi: 0.6989700049161911
# 0.6989700039848685
# 4.999999995957233
# lo: 0.6989700039848685, hi: 0.6989700049161911
# 0.6989700044505298
# 5.000000001318357
# lo: 0.6989700039848685, hi: 0.6989700044505298
# 0.6989700042176992
# 4.9999999986377945
# lo: 0.6989700042176992, hi: 0.6989700044505298
# 0.6989700043341145
# 4.999999999978076
# lo: 0.6989700043341145, hi: 0.6989700044505298
# 0.6989700043923222
# 5.000000000648217
# lo: 0.6989700043341145, hi: 0.6989700043923222
# 0.6989700043632183
# 5.000000000313146
# lo: 0.6989700043341145, hi: 0.6989700043632183
# 0.6989700043486664
# 5.000000000145611
# lo: 0.6989700043341145, hi: 0.6989700043486664
# 0.6989700043413904
# 5.000000000061843
# ...

# %%
log10(5)
# Out:
# 0.6989700043360189

# %%
10**log10(5)
# Out:
# 5.000000000000001

# %%
# log10(9)
# log10(10) == 1, log10(1) == 0
num = 9
guess =

# %%
10**.5
# Out:
# 3.1622776601683795

# %%
10**.75
# Out:
# 5.623413251903491

# %%
# function
123
123 / 10
# Out:
# 12.3

# %%
123 / 10 / 10
# Out:
# 1.23

# %%
1235 // 10
# Out:
# 123

# %%
1235 % 10
# Out:
# 5

# %%
lo = 1
hi = 10

Pick a number between 1 and 10**10 and find it log.
